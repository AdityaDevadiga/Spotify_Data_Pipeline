# %%
# !pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
client_credentials_manager = SpotifyClientCredentials(client_id="",client_secret="5")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = ""

# %%
playlist_URI = playlist_link.split("/")[-1]

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
data['items'][0]['track']['album']['id']
# Out:
# '0IGNZGDA2Sjntx73xf8hV5'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Galtiyan'

# %%
data['items'][0]['track']['album']
# Out:
# {'album_type': 'single',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4YRxDV8wJFPHPTeXepOstw'},
#    'href': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw',
#    'id': '4YRxDV8wJFPHPTeXepOstw',
#    'name': 'Arijit Singh',
#    'type': 'artist',
#    'uri': 'spotify:artist:4YRxDV8wJFPHPTeXepOstw'}],
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
# ...

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2023-06-17'

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name =row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id': album_id,'album_name': album_name,'album_release_date' :album_release_date,'album_total_tracks': album_total_tracks,'album_url':album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '0IGNZGDA2Sjntx73xf8hV5',
#   'album_name': 'Galtiyan',
#   'album_release_date': '2023-06-17',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/0IGNZGDA2Sjntx73xf8hV5'},
#  {'album_id': '5xP2I1UDXhE7D4GpMOoZY9',
#   'album_name': 'Sanam Re',
#   'album_release_date': '2016-01-04',
#   'album_total_tracks': 8,
#   'album_url': 'https://open.spotify.com/album/5xP2I1UDXhE7D4GpMOoZY9'},
#  {'album_id': '59RFGu1upndkHRqpJWHvos',
#   'album_name': 'Yaariyan',
#   'album_release_date': '2013-12-09',
#   'album_total_tracks': 13,
#   'album_url': 'https://open.spotify.com/album/59RFGu1upndkHRqpJWHvos'},
#  {'album_id': '7kXEDaT5yy8IUT7Fmqs1i2',
#   'album_name': 'O Bedardeya (From "Tu Jhoothi Main Makkaar")',
#   'album_release_date': '2023-03-04',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/7kXEDaT5yy8IUT7Fmqs1i2'},
#  {'album_id': '2L1otdfoUvp3MKdaT4knVK',
#   'album_name': 'Rait Zara Si (From "Atrangi Re")',
# ...

# %%
data['items'][2]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6QtJ6BVdj43aDpgjnVp2tY'},
#   'href': 'https://api.spotify.com/v1/artists/6QtJ6BVdj43aDpgjnVp2tY',
#   'id': '6QtJ6BVdj43aDpgjnVp2tY',
#   'name': 'Mohammed Irfan',
#   'type': 'artist',
#   'uri': 'spotify:artist:6QtJ6BVdj43aDpgjnVp2tY'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/1yzgJmZf5CxtFfGfRFm4Si'},
#   'href': 'https://api.spotify.com/v1/artists/1yzgJmZf5CxtFfGfRFm4Si',
#   'id': '1yzgJmZf5CxtFfGfRFm4Si',
#   'name': 'Gajendra Verma',
#   'type': 'artist',
#   'uri': 'spotify:artist:1yzgJmZf5CxtFfGfRFm4Si'}]

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == 'track':
            for artist in value['artists']:
                artist_dict = {'artist_id':artist['id'],'artist_name':artist['name'],'external_url':artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '09UmIX92EUH9hAK4bxvHx6',
#   'artist_name': 'Mithoon',
#   'external_url': 'https://api.spotify.com/v1/artists/09UmIX92EUH9hAK4bxvHx6'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '6QtJ6BVdj43aDpgjnVp2tY',
#   'artist_name': 'Mohammed Irfan',
#   'external_url': 'https://api.spotify.com/v1/artists/6QtJ6BVdj43aDpgjnVp2tY'},
#  {'artist_id': '1yzgJmZf5CxtFfGfRFm4Si',
#   'artist_name': 'Gajendra Verma',
#   'external_url': 'https://api.spotify.com/v1/artists/1yzgJmZf5CxtFfGfRFm4Si'},
#  {'artist_id': '1wRPtKGflJrBx9BmLsSwlU',
#   'artist_name': 'Pritam',
#   'external_url': 'https://api.spotify.com/v1/artists/1wRPtKGflJrBx9BmLsSwlU'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
# ...

# %%
song_list = [] 
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,'popularoty':song_popularity,'song_added':song_added,'álbum_id':album_id,'artist_id':artist_id}
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '2RQbfbmqh13otxU98ngG2F',
#   'song_name': 'Galtiyan',
#   'duration_ms': 302250,
#   'url': 'https://open.spotify.com/track/2RQbfbmqh13otxU98ngG2F',
#   'popularoty': 43,
#   'song_added': '1970-01-01T00:00:00Z',
#   'álbum_id': '0IGNZGDA2Sjntx73xf8hV5',
#   'artist_id': '4YRxDV8wJFPHPTeXepOstw'},
#  {'song_id': '0CVfovmUv7BnemOyTtOcbL',
#   'song_name': 'Sanam Re',
#   'duration_ms': 308714,
#   'url': 'https://open.spotify.com/track/0CVfovmUv7BnemOyTtOcbL',
#   'popularoty': 69,
#   'song_added': '1970-01-01T00:00:00Z',
#   'álbum_id': '5xP2I1UDXhE7D4GpMOoZY9',
#   'artist_id': '0LyfQWJT6nXafLPZqxe9Of'},
#  {'song_id': '6ABHr8kYCws5z6gC9Lwith',
#   'song_name': 'Baarish',
#   'duration_ms': 374938,
#   'url': 'https://open.spotify.com/track/6ABHr8kYCws5z6gC9Lwith',
#   'popularoty': 69,
#   'song_added': '1970-01-01T00:00:00Z',
#   'álbum_id': '59RFGu1upndkHRqpJWHvos',
#   'artist_id': '0LyfQWJT6nXafLPZqxe9Of'},
#  {'song_id': '0czcoKJbJt08NqKrvSbbz7',
# ...

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id                                    album_name  \
# 0  0IGNZGDA2Sjntx73xf8hV5                                      Galtiyan
# 1  5xP2I1UDXhE7D4GpMOoZY9                                      Sanam Re
# 2  59RFGu1upndkHRqpJWHvos                                      Yaariyan
# 3  7kXEDaT5yy8IUT7Fmqs1i2  O Bedardeya (From "Tu Jhoothi Main Makkaar")
# 4  2L1otdfoUvp3MKdaT4knVK              Rait Zara Si (From "Atrangi Re")
#
#   album_release_date  album_total_tracks  \
# 0         2023-06-17                   1
# 1         2016-01-04                   8
# 2         2013-12-09                  13
# 3         2023-03-04                   1
# 4         2021-12-06                   1
#
#                                            album_url
# 0  https://open.spotify.com/album/0IGNZGDA2Sjntx7...
# 1  https://open.spotify.com/album/5xP2I1UDXhE7D4G...
# 2  https://open.spotify.com/album/59RFGu1upndkHRq...
# 3  https://open.spotify.com/album/7kXEDaT5yy8IUT7...
# ...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   album_id            50 non-null     object
#  1   album_name          50 non-null     object
#  2   album_release_date  50 non-null     object
#  3   album_total_tracks  50 non-null     int64
#  4   album_url           50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
album_df = album_df.drop_duplicates(subset = ['album_id'])

# %%
album_df
# Out:
#                   album_id                                         album_name  \
# 0   0IGNZGDA2Sjntx73xf8hV5                                           Galtiyan
# 1   5xP2I1UDXhE7D4GpMOoZY9                                           Sanam Re
# 2   59RFGu1upndkHRqpJWHvos                                           Yaariyan
# 3   7kXEDaT5yy8IUT7Fmqs1i2       O Bedardeya (From "Tu Jhoothi Main Makkaar")
# 4   2L1otdfoUvp3MKdaT4knVK                   Rait Zara Si (From "Atrangi Re")
# 5   7vQKtc0edApiep4Xdt1bHm                   Khamoshiyan (From "Khamoshiyan")
# 6   1IwC3SdQXPgXSs8FLvOUju                                            Airlift
# 7   3I8PdIhk6pNm8Kv0HiF14V       Tujhe Kitna Chahne Lage (From "Kabir Singh")
# 8   4c5CZEoxiWQs8KugdzpvJd              Aashiqui Aa Gayi (From "Radhe Shyam")
# 9   2ooWY7xriwwyj23dAI32C2                                            Pathaan
# 10  4dYNdtPc5EUSmKtyZ9x0l0                              Best Of Palak Muchhal
# ...

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
artist_df
# Out:
#                   artist_id           artist_name  \
# 0    4YRxDV8wJFPHPTeXepOstw          Arijit Singh
# 1    09UmIX92EUH9hAK4bxvHx6               Mithoon
# 3    6QtJ6BVdj43aDpgjnVp2tY        Mohammed Irfan
# 4    1yzgJmZf5CxtFfGfRFm4Si        Gajendra Verma
# 5    1wRPtKGflJrBx9BmLsSwlU                Pritam
# 7    2fMqTqiTxUDlmcOEPaQSsx  Amitabh Bhattacharya
# 8    1mYsTxnqsietFxj1OgoGbG           A.R. Rahman
# 10   12CpR4SNDzVIlDoPSeNFeW      Shashaa Tirupati
# 11   2kkQthS9OLpK4UqNWYqoVl         Jeet Gannguli
# 13   76fuWYgIf3TVIopTs3vaJ6          Amaal Mallik
# 15   0T1CMVkqffHlqEk4BcAph1           Tulsi Kumar
# 20   6Mv8GjQa7LKUGCAqa9qqdb        Vishal-Shekhar
# 22   3FgHkfb3IqG4WKuVe1xCXM         Sukriti Kakar
# 23   6CXEwIaXYfVJ84biCxqc9k        Vishal Dadlani
# 24   4xd7mLI7urqrxELaXhAvzw      Shekhar Ravjiani
# 25   0m3D4grap8VFSzbJMqgNVk                Kumaar
# 26   3yMmYEklQ7gLOZXEFNd3xr         Palak Muchhal
# 28   7EiUTtmmkwGtbgR6gZaZzW         Kaushik-Guddu
# ...

# %%
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df
# Out:
#                    song_id                                          song_name  \
# 0   2RQbfbmqh13otxU98ngG2F                                           Galtiyan
# 1   0CVfovmUv7BnemOyTtOcbL                                           Sanam Re
# 2   6ABHr8kYCws5z6gC9Lwith                                            Baarish
# 3   0czcoKJbJt08NqKrvSbbz7       O Bedardeya (From "Tu Jhoothi Main Makkaar")
# 4   4uK0M8AI6gyFmyzUneQpbi                   Rait Zara Si (From "Atrangi Re")
# 5   5Gy67YHzPZTk9Q0D73LAGH                   Khamoshiyan (From "Khamoshiyan")
# 6   6mTvwBzWTGDOVeCNQEqtOE                                       Soch Na Sake
# 7   2Fv2injs4qAm8mJBGaxVKU       Tujhe Kitna Chahne Lage (From "Kabir Singh")
# 8   7I6mwEFQwpTu5ciVZWFpd4               Aashiqui Aa Gayi(From "Radhe Shyam")
# 9   6FAYpZ4jve8vpvTwUvjK6H                                  Jhoome Jo Pathaan
# 10  7Imk0IG6S5GA5iYWkjmMW5             Chahun Main Ya Naa (From "Aashiqui 2")
# ...

# %%
song_df.head()
# Out:
#                   song_id                                     song_name  \
# 0  2RQbfbmqh13otxU98ngG2F                                      Galtiyan
# 1  0CVfovmUv7BnemOyTtOcbL                                      Sanam Re
# 2  6ABHr8kYCws5z6gC9Lwith                                       Baarish
# 3  0czcoKJbJt08NqKrvSbbz7  O Bedardeya (From "Tu Jhoothi Main Makkaar")
# 4  4uK0M8AI6gyFmyzUneQpbi              Rait Zara Si (From "Atrangi Re")
#
#    duration_ms                                                url  popularoty  \
# 0       302250  https://open.spotify.com/track/2RQbfbmqh13otxU...          43
# 1       308714  https://open.spotify.com/track/0CVfovmUv7BnemO...          69
# 2       374938  https://open.spotify.com/track/6ABHr8kYCws5z6g...          69
# 3       313051  https://open.spotify.com/track/0czcoKJbJt08NqK...          78
# 4       291462  https://open.spotify.com/track/4uK0M8AI6gyFmyz...          75
#
# ...

# %%
artist_df.head()
# Out:
#                 artist_id     artist_name  \
# 0  4YRxDV8wJFPHPTeXepOstw    Arijit Singh
# 1  09UmIX92EUH9hAK4bxvHx6         Mithoon
# 3  6QtJ6BVdj43aDpgjnVp2tY  Mohammed Irfan
# 4  1yzgJmZf5CxtFfGfRFm4Si  Gajendra Verma
# 5  1wRPtKGflJrBx9BmLsSwlU          Pritam
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/4YRxDV8wJFP...
# 1  https://api.spotify.com/v1/artists/09UmIX92EUH...
# 3  https://api.spotify.com/v1/artists/6QtJ6BVdj43...
# 4  https://api.spotify.com/v1/artists/1yzgJmZf5Cx...
# 5  https://api.spotify.com/v1/artists/1wRPtKGflJr...

# %%
album_df['album_release_date'] = pd.to_datetime(album_df['album_release_date'])
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_31272\2236237792.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   album_df['album_release_date'] = pd.to_datetime(album_df['album_release_date'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 47 entries, 0 to 47
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   album_id            47 non-null     object
#  1   album_name          47 non-null     object
#  2   album_release_date  47 non-null     datetime64[ns]
#  3   album_total_tracks  47 non-null     int64
#  4   album_url           47 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 2.2+ KB

# %%
album_df.head()
# Out:
#                  album_id                                    album_name  \
# 0  0IGNZGDA2Sjntx73xf8hV5                                      Galtiyan
# 1  5xP2I1UDXhE7D4GpMOoZY9                                      Sanam Re
# 2  59RFGu1upndkHRqpJWHvos                                      Yaariyan
# 3  7kXEDaT5yy8IUT7Fmqs1i2  O Bedardeya (From "Tu Jhoothi Main Makkaar")
# 4  2L1otdfoUvp3MKdaT4knVK              Rait Zara Si (From "Atrangi Re")
#
#   album_release_date  album_total_tracks  \
# 0         2023-06-17                   1
# 1         2016-01-04                   8
# 2         2013-12-09                  13
# 3         2023-03-04                   1
# 4         2021-12-06                   1
#
#                                            album_url
# 0  https://open.spotify.com/album/0IGNZGDA2Sjntx7...
# 1  https://open.spotify.com/album/5xP2I1UDXhE7D4G...
# 2  https://open.spotify.com/album/59RFGu1upndkHRq...
# 3  https://open.spotify.com/album/7kXEDaT5yy8IUT7...
# ...

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added'])

# %%
song_df.head()
# Out:
#                   song_id                                     song_name  \
# 0  2RQbfbmqh13otxU98ngG2F                                      Galtiyan
# 1  0CVfovmUv7BnemOyTtOcbL                                      Sanam Re
# 2  6ABHr8kYCws5z6gC9Lwith                                       Baarish
# 3  0czcoKJbJt08NqKrvSbbz7  O Bedardeya (From "Tu Jhoothi Main Makkaar")
# 4  4uK0M8AI6gyFmyzUneQpbi              Rait Zara Si (From "Atrangi Re")
#
#    duration_ms                                                url  popularoty  \
# 0       302250  https://open.spotify.com/track/2RQbfbmqh13otxU...          43
# 1       308714  https://open.spotify.com/track/0CVfovmUv7BnemO...          69
# 2       374938  https://open.spotify.com/track/6ABHr8kYCws5z6g...          69
# 3       313051  https://open.spotify.com/track/0czcoKJbJt08NqK...          78
# 4       291462  https://open.spotify.com/track/4uK0M8AI6gyFmyz...          75
#
# ...

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      50 non-null     object
#  1   song_name    50 non-null     object
#  2   duration_ms  50 non-null     int64
#  3   url          50 non-null     object
#  4   popularoty   50 non-null     int64
#  5   song_added   50 non-null     datetime64[ns, UTC]
#  6   álbum_id     50 non-null     object
#  7   artist_id    50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.3+ KB
